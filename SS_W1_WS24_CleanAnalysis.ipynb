# %%
import pandas as pd

# %%
df_w1 = pd.read_csv("/Users/ramius/Desktop/CodeVault/01_Project/Work/Susumu/Student_Survey/OTree_StudentSurvey/StudentSurvey/W1_AllAppsWide_2024-11-13-4.csv")

# %%
df_w1 = df_w1.dropna(subset=['network_app.1.player.participantcode'])

# %%
df_w1
# Out:
#      participant.id_in_session participant.code  participant.label  \
# 9                            1         fr2ubu6a                NaN
# 12                           1         16myjuax                NaN
# 13                           2         wdw1ump6                NaN
# 15                           1         ib464bdk                NaN
# 16                           2         b75qt10l                NaN
# ..                         ...              ...                ...
# 252                         23         t0dnwmxs                NaN
# 253                         24         1f4xq3cy                NaN
# 259                         30         iahzsgw7                NaN
# 260                         31         sazq8up1                NaN
# 261                         32         9ycillyr                NaN
#
#      participant._is_bot  participant._index_in_pages  \
# 9                      0                            8
# ...
